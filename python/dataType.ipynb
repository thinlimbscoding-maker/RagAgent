# %%
a=[1,2,3,4]
print(a)

# %% [markdown]
# #### data type in python
#  1. List just kind fo array
#  2. Tuple
#  3. Set
#  4. Dictionary

# %% [markdown]
# #### tupple like syntax like function
# a=(1,2,3)
# b,c=a

# %% [markdown]
# source python/venv/bin/activate
# commad to active venv
