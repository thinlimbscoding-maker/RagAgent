# %%
class A:
name="kunal"

def __init__(self):


@classmethod  
def changeName(cls,changeName):
cls.name=changeName
obj1 =A()
obj1.changeName("newname")
obj1.

# %% [markdown]
# class is basic model of anything
# which has its all basic property
# there is way to acces clsss properties
# via obj
# eg
# obj1=MyobjectClass()
# when ever u make class object at time its inovke its constaructor firt
#
# there are some to change class propertu
# class A:
# name="kunal"
#
#
# class A:
#     name = "kunal"
#
#     @classmethod
#     def changeName(cls, newName):
#         cls.name = newName
#
#
# obj1 = A()
# obj1.changeName("sanjya")
# print(A.name)
#
# now its changes it value
#
#
# and static  method it does not  contain slef or cls it just for normal opreation
