# %% [markdown]
# #### there is  main 4 type  mode
#  1. 'r' read if file exist if not rasie error
#  2. 'w' open files and owrite existing content if file there if not makes new file
#  3. 'a' append open file to add data at then end does not delete
#  4. 'x' craete a file rasie error if alredy there
